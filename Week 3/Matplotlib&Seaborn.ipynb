# %%
import matplotlib.pyplot as plt
import numpy as np

# Enable inline plotting in Jupyter
# %matplotlib inline

# Set style
import seaborn as sns
sns.set_theme()

# Create figure and axis objects
fig, ax = plt.subplots(figsize=(10, 6))

# Line plot
plt.plot(x, y, label='line', color='blue', linestyle='-', linewidth=2, marker='o')

# Scatter plot
plt.scatter(x, y, c='red', s=50, alpha=0.5, label='points')

# Bar plot
plt.bar(x, height, width=0.8, align='center', color='green')

# Histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black')

# Box plot
plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12 fig, ax = plt.subplots(figsize=(10, 6))
#      14 # Line plot
# ---> 15 plt.plot(x, y, label='line', color='blue', linestyle='-', linewidth=2, marker='o')
#      17 # Scatter plot
#      18 plt.scatter(x, y, c='red', s=50, alpha=0.5, label='points')
#
# NameError: name 'x' is not defined
